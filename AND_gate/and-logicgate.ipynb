# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Print NOR gate truth table
def and_gate(a, b):
    return (a and b)

print("A\tB\tOutput")
print("-"*25)
for a in [False, True]:
    for b in [False, True]:
        output = and_gate(a, b)
        print(f"{a}\t{b}\t{output}")
# Out:
# A	B	Output
# -------------------------
# False	False	False
# False	True	False
# True	False	False
# True	True	True

# %%
#create input data
training_inputs = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
training_outputs = np.array([[0], [0], [0], [1]], dtype=np.float32)

# %%
# model creation
i = tf.keras.Input(2,)
x = tf.keras.layers.Dense(8, activation='relu')(i)
x = tf.keras.layers.Dense(16, activation='relu')(x)
x = tf.keras.layers.Dense(32, activation='tanh')(x)
x = tf.keras.layers.Dense(8, activation='tanh')(x)
x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
model = tf.keras.models.Model(i,x)

# %%
#model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  dense (Dense)               (None, 8)                 24
#
#  dense_1 (Dense)             (None, 16)                144
#
#  dense_2 (Dense)             (None, 32)                544
#
#  dense_3 (Dense)             (None, 8)                 264
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling model
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics='accuracy')

# %%
#fitting the model
r = model.fit(training_inputs,training_outputs,epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.2493 - accuracy: 0.7500
# Epoch 2/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2476 - accuracy: 0.7500
# Epoch 3/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2457 - accuracy: 1.0000
# Epoch 4/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2439 - accuracy: 1.0000
# Epoch 5/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2420 - accuracy: 0.7500
# Epoch 6/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2401 - accuracy: 0.7500
# Epoch 7/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2382 - accuracy: 0.7500
# Epoch 8/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2362 - accuracy: 0.7500
# Epoch 9/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2342 - accuracy: 0.7500
# Epoch 10/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2322 - accuracy: 0.7500
# Epoch 11/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2302 - accuracy: 0.7500
# Epoch 12/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2280 - accuracy: 0.7500
# Epoch 13/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2259 - accuracy: 0.7500
# Epoch 14/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2237 - accuracy: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2214 - accuracy: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2191 - accuracy: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2167 - accuracy: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2143 - accuracy: 1.0000
# Epoch 19/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2118 - accuracy: 1.0000
# Epoch 20/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2092 - accuracy: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2066 - accuracy: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2040 - accuracy: 1.0000
# Epoch 23/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2013 - accuracy: 1.0000
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1986 - accuracy: 1.0000
# Epoch 25/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1957 - accuracy: 1.0000
# Epoch 26/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1928 - accuracy: 1.0000
# Epoch 27/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1898 - accuracy: 1.0000
# Epoch 28/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1868 - accuracy: 1.0000
# Epoch 29/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1837 - accuracy: 1.0000
# Epoch 30/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1806 - accuracy: 1.0000
# Epoch 31/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1774 - accuracy: 1.0000
# Epoch 32/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1742 - accuracy: 1.0000
# Epoch 33/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1709 - accuracy: 1.0000
# Epoch 34/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1675 - accuracy: 1.0000
# Epoch 35/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1642 - accuracy: 1.0000
# Epoch 36/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1608 - accuracy: 1.0000
# Epoch 37/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1573 - accuracy: 1.0000
# Epoch 38/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1538 - accuracy: 1.0000
# Epoch 39/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1503 - accuracy: 1.0000
# Epoch 40/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1467 - accuracy: 1.0000
# Epoch 41/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1431 - accuracy: 1.0000
# Epoch 42/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 1.0000
# Epoch 43/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1359 - accuracy: 1.0000
# Epoch 44/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1322 - accuracy: 1.0000
# Epoch 45/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1286 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1250 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1213 - accuracy: 1.0000
# Epoch 48/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1177 - accuracy: 1.0000
# Epoch 49/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1141 - accuracy: 1.0000
# Epoch 50/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1105 - accuracy: 1.0000

# %%
# model prediction
test_input = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
predictions = model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 135ms/step

# %%
# Print the predicted outputs for the NOR gate
for i in range(len(test_input)):
    print("Input: {} Predicted Output: {}".format(test_input[i],predictions[i].round()))
# Out:
# Input: [0. 0.] Predicted Output: [0.]
# Input: [0. 1.] Predicted Output: [0.]
# Input: [1. 0.] Predicted Output: [0.]
# Input: [1. 1.] Predicted Output: [1.]

# %%
plt.plot(r.history['accuracy'],label='accuracy')
plt.xlabel('epoch')
plt.legend()

# %%
plt.plot(r.history['loss'],label='loss')
plt.xlabel('epoch')
plt.legend()

# %%
model.save("and_logic_gate.h5")
